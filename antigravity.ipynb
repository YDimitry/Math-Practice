# %%
import  matplotlib.pyplot  as  plt

# %matplotlib inline

# %%
for i in range(4):
    if i:
        ax = plt.subplot2grid((2, 3), (1, i-1))        
    else:
        ax = plt.subplot2grid((2, 3), (0, 0), colspan=3)
        ax.figure.set_size_inches(7, 7)
        # ax.figure.set_figwidth(7)
        # ax.figure.set_figheight(7)
    with open(str(i+1)+'.png', 'rb') as p:
        img = plt.imread(p)        
    ax.imshow(img)
    ax.set_title(img.shape)
    # ax.get_xaxis().set_visible(False)
    # ax.get_yaxis().set_visible(False)
# plt.subplots_adjust(left=None, bottom=None, right=0.5, top=None,
#                       wspace=None, hspace=0.1)
# plt.gca().set_aspect('equal', adjustable='box')





# fig = plt.figure()
with open('1.png', 'rb') as p1, open('2.png', 'rb') as p2,\
 open('3.png', 'rb') as p3, open('4.png', 'rb') as p4:
    img1 = plt.imread(p1)
    img2 = plt.imread(p2)
    img3 = plt.imread(p3)
    img4 = plt.imread(p4)
# ax1 = plt.subplot2grid((2, 3), (0, 0), colspan=3)
# ax1.imshow(img1)
# ax1.set_axis_off()
# ax2 = plt.subplot2grid((2, 3), (1, 0))
# ax2.imshow(img2)
# ax3 = plt.subplot2grid((2, 3), (1, 1))
# ax3.imshow(img3)
# ax4 = plt.subplot2grid((2, 3), (1, 2))
# ax4.imshow(img4)

# %%
plt.figure(figsize=(8,11))


ax1 = plt.subplot(211)
# ax1.margins(0.05)           # Default margin is 0.05, value 0 means fit
ax1.imshow(img1)
# ax1.axis('off')
# ax1.autoscale(False)


ax2 = plt.subplot(234)
# ax2.margins(2, 2)           # Values >0.0 zoom out
ax2.imshow(img2)
# ax2.axis('off')
# ax2.autoscale(False)

ax3 = plt.subplot(235,sharey=ax2)
ax3.margins(x=0, y=-0.25)   # Values in (-0.5, 0.0) zooms in to center
ax3.imshow(img3)
# ax3.axis('off')
ax3.autoscale(True)

ax4 = plt.subplot(236,sharey=ax2)
# ax3.margins(x=0, y=-0.25)   # Values in (-0.5, 0.0) zooms in to center
ax4.imshow(img4)
# ax4.axis('off')
ax4.autoscale(True)

plt.subplots_adjust(left=0.2, bottom=None, right=0.9, top=None,
                      wspace=0.01, hspace=0.2)

# plt.figure(figsize=(20,20))
# plt.show()

# %%
# import matplotlib.gridspec as gridspec
# height_ratios=[1,1]
# fig = plt.figure(figsize=(10, 16))

# grid = gridspec.GridSpec(2,3,hspace=0.2, wspace=0.2)
# ax1 = fig.add_subplot(grid[0,:])
# ax1.axis('off')
# ax1.set_title(img1.shape)
# ax1.imshow(img1)
# ax2 = fig.add_subplot(grid[1,0])
# ax2.imshow(img2)
# ax2.axis('off')
# ax2.set_title(img2.shape)
# ax2.autoscale(False)

# ax3 = fig.add_subplot(grid[1,1])
# ax3.imshow(img3)
# ax3.autoscale(False)

# ax4 = fig.add_subplot(grid[1,2])
# ax4.imshow(img4)
# ax4.autoscale(False)
# plt.gca().set_aspect('equal', adjustable='box')

# %%
# fig, (ax2, ax3, ax4) = plt.subplots(2, 3, figsize=(15, 6))

# ax1 = plt.subplot(211)
# ax1.imshow(img1)

# ax2.imshow(img2)
# ax3.imshow(img3)
# ax4.imshow(img4)
# plt.subplots_adjust(left=None, bottom=None, right=0.9, top=None,
#                       wspace=0.01, hspace=0.1)

# %%
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(7, 10))
# , wspace=0.01,hspace=0.5
grid = gridspec.GridSpec(3,3)

ax1 = fig.add_subplot(grid[:2,:])
ax2 = fig.add_subplot(grid[2,0])
ax3 = fig.add_subplot(grid[2,1],sharey=ax2)
ax4 = fig.add_subplot(grid[2,2],sharey=ax2)

ax1.imshow(img1)
ax2.imshow(img2)
ax3.imshow(img3)
ax4.imshow(img4)

ax1.axis('off')
ax2.axis('off')
ax3.axis('off')
ax4.axis('off')

plt.show()

# %%
fig = plt.figure(figsize=(16, 10))

ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3, rowspan=2)
ax1.imshow(img1)
ax2 = plt.subplot2grid((3, 3), (2, 0))     
ax2.imshow(img2)
ax3 = plt.subplot2grid((3, 3), (2, 1))
ax3.imshow(img3)
ax4 = plt.subplot2grid((3, 3), (2, 2))
ax4.imshow(img4)
ax1.set_title(img1.shape)

# ax.figure.set_figwidth(7)
# ax.figure.set_figheight(7)
# Out:
# Text(0.5, 1.0, '(321, 518, 4)')
